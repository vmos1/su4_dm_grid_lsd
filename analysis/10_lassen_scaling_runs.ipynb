# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import itertools

# %%
# %matplotlib notebook

# %%
Nc=[4,4,3,3]
Vol=['16_8','32_16','16_8','32_16']
rank1=[180,2770,140,1605]
rank2=[120,1440,105,820]
rank4=[93,796,90,475]
rank8=[75,490,78,330]

# %%
cols=['nc','vol','rank1','rank2','rank4','rank8']
df=pd.DataFrame(zip(Nc,Vol,rank1,rank2,rank4,rank8),columns=cols)
df
# Out:
#    nc    vol  rank1  rank2  rank4  rank8
# 0   4   16_8    180    120     93     75
# 1   4  32_16   2770   1440    796    490
# 2   3   16_8    140    105     90     78
# 3   3  32_16   1605    820    475    330

# %%
cls=[i for i in df.columns if i.startswith('rank')]

# %%
df.loc[1][cls]/df.loc[0][cls]
# Out:
# rank1    15.388889
# rank2         12.0
# rank4      8.55914
# rank8     6.533333
# dtype: object

# %%
df.loc[3][cls]/df.loc[2][cls]
# Out:
# rank1    11.464286
# rank2     7.809524
# rank4     5.277778
# rank8     4.230769
# dtype: object

# %%
df.loc[0][cls]/df.loc[2][cls]
# Out:
# rank1    1.285714
# rank2    1.142857
# rank4    1.033333
# rank8    0.961538
# dtype: object

# %%
df.loc[1][cls]/df.loc[3][cls]
# Out:
# rank1    1.725857
# rank2    1.756098
# rank4    1.675789
# rank8    1.484848
# dtype: object

# %%
(4/3)**2
# Out:
# 1.7777777777777777

# %% [markdown]
# ### Plots

# %%
# Plot all 

plt.figure()
x=[1,2,4,8]

for (i,j),marker in zip(df.iterrows(),itertools.cycle('>^*sDHPdpx_')):
    y=j[['rank1','rank2','rank4','rank8']].values
    label='Nc='+str(j['nc'])+'_'+j.vol
    print(y,label)
    plt.plot(x,y,label=label,marker=marker)
    
plt.ylabel('Time per trajectory',rotation='vertical')
plt.xlabel('# of GPUs')
plt.legend()
# plt.show()
plt.yscale('log')
plt.savefig('scaling.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [180 120 93 75] Nc=4_16_8
# [2770 1440 796 490] Nc=4_32_16
# [140 105 90 78] Nc=3_16_8
# [1605 820 475 330] Nc=3_32_16

# %%
# j[['rank1','rank2','rank4','rank8']].values
# Out:
# array([1605, 820, 475, 330], dtype=object)

# %%
# Plot all 

plt.figure()
x=[1,2,4,8]

for (i,j),marker in zip(df[df.vol=='16_8'].iterrows(),itertools.cycle('>^*sDHPdpx_')):
    y=j[['rank1','rank2','rank4','rank8']].values
    label='Nc='+str(j['nc'])+'_'+j.vol
#     print(y,label)
    plt.plot(x,y,label=label,marker=marker)
    
plt.ylabel('Time per trajectory',rotation='vertical')
plt.xlabel('# of GPUs')
plt.legend()
# plt.show()
plt.savefig('scaling.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Plot all 

plt.figure()
x=[1,2,4,8]

for (i,j),marker in zip(df[df.nc==4].iterrows(),itertools.cycle('>^*sDHPdpx_')):
    y=j[['rank1','rank2','rank4','rank8']].values
    label='Nc='+str(j['nc'])+'_'+j.vol
#     print(y,label)
    plt.plot(x,y,label=label,marker=marker)
    
plt.ylabel('Time per trajectory',rotation='vertical')
plt.xlabel('# of GPUs')
plt.legend()
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
